# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pymongo

# %%
col_names = pd.read_csv("portland.csv", nrows = 0).columns
col_names
# Out:
# Index(['id', 'name', 'address', 'city', 'state', 'postal_code', 'latitude',
#        'longitude', 'stars', 'review_count', 'categories'],
#       dtype='object')

# %%
dtypes_dict = {
    "latitude": float,
    "longitude": float,
    "stars": float,
    "review_count": int,
}

# %%
df = pd.read_csv("portland.csv")
df = df.dropna()
df
# Out:
#         id                           name                    address  \
# 0        0        Flying Elephants at PDX        7000 NE Airport Way
# 1        1  Cleary's Restaurant & Spirits         12429 NE Glisan St
# 2        2                     Cafe Yumm!         301 SW Morrison St
# 4        4          B Street Coffee House         2190 W Burnside St
# 5        5                   Urban Pantry         1128 NW Lovejoy St
# ...    ...                            ...                        ...
# 5725  5725     McMenamins Barley Mill Pub  1629 S.E. Hawthorne Blvd.
# 5726  5726                       Seaplane         2266 NW Lovejoy St
# 5727  5727              The Italian Joint     3145 SE Hawthorne Blvd
# 5728  5728                    Chart House        5700 SW Terwilliger
# 5729  5729                    Havana Cafe             910 NW 14th St
#
#           city state  postal_code   latitude   longitude  stars  review_count  \
# 0     Portland    OR      97218.0  45.588906 -122.593331    4.0           126
# 1     Portland    OR      97230.0  45.526473 -122.535323    3.5            19
# 2     Portland    OR      97204.0  45.518450 -122.675723    3.5           158
# 4     Portland    OR      97210.0  45.523074 -122.696206    4.5           131
# 5     Portland    OR      97209.0  45.529939 -122.682932    3.5            26
# ...        ...   ...          ...        ...         ...    ...           ...
# 5725  Portland    OR      97214.0  45.512422 -122.648782    3.5           108
# 5726  Portland    OR      97210.0  45.529592 -122.697685    3.5            13
# 5727  Portland    OR      97203.0  45.512196 -122.632865    3.5            20
# 5728  Portland    OR      97239.0  45.483154 -122.682748    3.5           457
# 5729  Portland    OR      97209.0  45.529647 -122.685153    4.0            10
#
#                                              categories
# 0     Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 1           Nightlife, Sandwiches, Seafood, Restaurants
# 2     Vegetarian, Vegan, Sandwiches, Soup, American ...
# 4     Restaurants, Food, Sandwiches, Breakfast & Bru...
# 5     Do-It-Yourself Food, Restaurants, American (Tr...
# ...                                                 ...
# 5725  Pubs, Breweries, Food, American (Traditional),...
# 5726  Fashion, Men's Clothing, Restaurants, Shopping...
# 5727                               Italian, Restaurants
# 5728  Event Planning & Services, Steakhouses, Seafoo...
# 5729              Cuban, Sandwiches, Restaurants, Cafes
#
# [5682 rows x 11 columns]

# %%
df.dtypes
# Out:
# id                int64
# name             object
# address          object
# city             object
# state            object
# postal_code     float64
# latitude        float64
# longitude       float64
# stars           float64
# review_count      int64
# categories       object
# dtype: object

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.restaurant_db
restaurant = db.restaurant

# %%
restaurant.insert_many(df.to_dict('records'))

# %%
from pprint import pprint

for record in restaurant.find():
    pprint(record)
# Out:
# {'_id': ObjectId('61aaf3fd66f88d91729b177d'),
#  'address': '7000 NE Airport Way',
#  'categories': 'Salad, Soup, Sandwiches, Delis, Restaurants, Cafes, Vegetarian',
#  'city': 'Portland',
#  'id': 0,
#  'latitude': 45.5889058992,
#  'longitude': -122.5933307507,
#  'name': 'Flying Elephants at PDX',
#  'postal_code': 97218.0,
#  'review_count': 126,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b177e'),
#  'address': '12429 NE Glisan St',
#  'categories': 'Nightlife, Sandwiches, Seafood, Restaurants',
#  'city': 'Portland',
#  'id': 1,
#  'latitude': 45.5264727,
#  'longitude': -122.535323,
#  'name': "Cleary's Restaurant & Spirits",
#  'postal_code': 97230.0,
#  'review_count': 19,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b177f'),
#  'address': '301 SW Morrison St',
#  'categories': 'Vegetarian, Vegan, Sandwiches, Soup, American (New), Fast '
#                'Food, Restaurants, Wraps, American (Traditional)',
#  'city': 'Portland',
#  'id': 2,
#  'latitude': 45.5184501881,
#  'longitude': -122.6757229865,
#  'name': 'Cafe Yumm!',
#  'postal_code': 97204.0,
#  'review_count': 158,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1780'),
#  'address': '2190 W Burnside St',
#  'categories': 'Restaurants, Food, Sandwiches, Breakfast & Brunch, '
#                'Gluten-Free, Coffee & Tea, Bagels',
#  'city': 'Portland',
#  'id': 4,
#  'latitude': 45.5230736,
#  'longitude': -122.6962064,
#  'name': 'B Street Coffee House',
#  'postal_code': 97210.0,
#  'review_count': 131,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1781'),
#  'address': '1128 NW Lovejoy St',
#  'categories': 'Do-It-Yourself Food, Restaurants, American (Traditional), '
#                'Active Life, Grocery, Food, Local Flavor, Specialty Food, Kids '
#                'Activities, Cafes, Delis',
#  'city': 'Portland',
#  'id': 5,
#  'latitude': 45.5299395,
#  'longitude': -122.6829322,
#  'name': 'Urban Pantry',
#  'postal_code': 97209.0,
#  'review_count': 26,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1782'),
#  'address': 'SW 1st And Columbia',
#  'categories': 'Restaurants, Mexican, Food Trucks, Food, Food Stands',
#  'city': 'Portland',
#  'id': 6,
#  'latitude': 45.5131986231,
#  'longitude': -122.6763805441,
#  'name': 'Taqueria So Mexican',
#  'postal_code': 97230.0,
#  'review_count': 28,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1783'),
#  'address': '4246 SE Belmont',
#  'categories': 'Sushi Bars, Restaurants',
#  'city': 'Portland',
#  'id': 7,
#  'latitude': 45.516382,
#  'longitude': -122.618593,
#  'name': 'Fukami Sushiya',
#  'postal_code': 97215.0,
#  'review_count': 17,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1784'),
#  'address': '611 NW 13th Ave',
#  'categories': 'Mexican, Restaurants, Tacos, Breakfast & Brunch',
#  'city': 'Portland',
#  'id': 8,
#  'latitude': 45.5274187,
#  'longitude': -122.6844472,
#  'name': "Papi Chulo's",
#  'postal_code': 97209.0,
#  'review_count': 180,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1785'),
#  'address': '310 SW 5th Ave',
#  'categories': 'Mediterranean, Food, Restaurants, Food Trucks',
#  'city': 'Portland',
#  'id': 9,
#  'latitude': 45.5210363,
#  'longitude': -122.6766335,
#  'name': 'Noah Halal',
#  'postal_code': 97204.0,
#  'review_count': 72,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1786'),
#  'address': '508 SW Broadway',
#  'categories': 'Coffee & Tea, Restaurants, Food',
#  'city': 'Portland',
#  'id': 10,
#  'latitude': 45.5205512296,
#  'longitude': -122.6787543126,
#  'name': "Peet's Coffee",
#  'postal_code': 97205.0,
#  'review_count': 73,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1787'),
#  'address': '101 SE 82nd Ave',
#  'categories': 'Delis, Restaurants, Caterers, Event Planning & Services, '
#                'Vietnamese',
#  'city': 'Portland',
#  'id': 11,
#  'latitude': 45.522063,
#  'longitude': -122.579848,
#  'name': 'Lotus Kitchen',
#  'postal_code': 97216.0,
#  'review_count': 21,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1788'),
#  'address': '537 SW 12th Ave',
#  'categories': 'Restaurants, Cafes, Food, Coffee & Tea',
#  'city': 'Portland',
#  'id': 12,
#  'latitude': 45.5214333486,
#  'longitude': -122.683917135,
#  'name': 'Never Coffee',
#  'postal_code': 97205.0,
#  'review_count': 49,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1789'),
#  'address': 'SW 2st Columbia St',
#  'categories': 'Food Stands, Thai, Soup, Restaurants',
#  'city': 'Portland',
#  'id': 13,
#  'latitude': 45.5130803159,
#  'longitude': -122.6762986556,
#  'name': 'Lai Thai Food Cart',
#  'postal_code': 97201.0,
#  'review_count': 20,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b178a'),
#  'address': '4237 N Mississippi Ave',
#  'categories': 'Restaurants, Food Trucks, Food Stands, Food, Middle Eastern, '
#                'Persian/Iranian, Mediterranean',
#  'city': 'Portland',
#  'id': 14,
#  'latitude': 45.554568,
#  'longitude': -122.675674,
#  'name': 'Caspian Kabob',
#  'postal_code': 97217.0,
#  'review_count': 187,
#  'stars': 5.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b178b'),
#  'address': '3582 SE Powell Blvd',
#  'categories': 'Restaurants, Cajun/Creole, Food, Southern, Food Trucks, '
#                'Donuts, Seafood',
#  'city': 'Portland',
#  'id': 15,
#  'latitude': 45.496485,
#  'longitude': -122.626764,
#  'name': "Matt & Memere's",
#  'postal_code': 97202.0,
#  'review_count': 34,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b178c'),
#  'address': '2207 NE Columbia Blvd',
#  'categories': 'Delis, Restaurants',
#  'city': 'Portland',
#  'id': 16,
#  'latitude': 45.5773886,
#  'longitude': -122.6430574,
#  'name': 'Kings Deli',
#  'postal_code': 97211.0,
#  'review_count': 15,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b178d'),
#  'address': '5810 NE Sandy Blvd',
#  'categories': 'Restaurants, Thai',
#  'city': 'Portland',
#  'id': 17,
#  'latitude': 45.5425541,
#  'longitude': -122.6033063,
#  'name': 'Cha Ba Thai',
#  'postal_code': 97213.0,
#  'review_count': 332,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b178e'),
#  'address': '2211 SE Hawthorne Blvd',
#  'categories': 'Food, Beer, Wine & Spirits, Restaurants, Fast Food, Pizza, '
#                'Gluten-Free',
#  'city': 'Portland',
#  'id': 18,
#  'latitude': 45.512154,
#  'longitude': -122.6431199,
#  'name': 'HOTLIPS Pizza - Hawthorne',
#  'postal_code': 97214.0,
#  'review_count': 177,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b178f'),
#  'address': '1001 SW Broadway',
#  'categories': 'Bars, Wine Bars, Food, Nightlife, Restaurants, Seafood, '
#                'Desserts',
#  'city': 'Portland',
#  'id': 19,
#  'latitude': 45.5172228,
#  'longitude': -122.6810692,
#  'name': 'Headwaters',
#  'postal_code': 97205.0,
#  'review_count': 307,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1790'),
#  'address': 'SW 10th & Alder St',
#  'categories': 'Food Stands, Food, Thai, Food Trucks, Bubble Tea, Restaurants',
#  'city': 'Portland',
#  'id': 20,
#  'latitude': 45.5205359903,
#  'longitude': -122.6816037297,
#  'name': 'A Thai Basil',
#  'postal_code': 97205.0,
#  'review_count': 41,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1791'),
#  'address': '12109 NE Glisan St',
#  'categories': 'Coffee & Tea, Restaurants, Fast Food, Burgers, Food',
#  'city': 'Portland',
#  'id': 21,
#  'latitude': 45.526686131,
#  'longitude': -122.5382611156,
#  'name': "McDonald's",
#  'postal_code': 97220.0,
#  'review_count': 37,
#  'stars': 1.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1792'),
#  'address': '1409 NE Alberta St',
#  'categories': 'Pubs, Restaurants, Nightlife, Breakfast & Brunch, Bars, '
#                'Japanese, Cocktail Bars',
#  'city': 'Portland',
#  'id': 22,
#  'latitude': 45.5591054,
#  'longitude': -122.6512761,
#  'name': 'Bamboo Izakaya',
#  'postal_code': 97211.0,
#  'review_count': 42,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1793'),
#  'address': '2875 SE Powell Blvd',
#  'categories': 'Food, Fast Food, Restaurants, Coffee & Tea, Burgers',
#  'city': 'Portland',
#  'id': 23,
#  'latitude': 45.4977464697,
#  'longitude': -122.6360719,
#  'name': "McDonald's",
#  'postal_code': 97202.0,
#  'review_count': 77,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1794'),
#  'address': '4110 SE Woodstock Blvd',
#  'categories': 'Juice Bars & Smoothies, Cafes, Mexican, Vegetarian, '
#                'Restaurants, American (New), Food, Vegan, Salad',
#  'city': 'Portland',
#  'id': 24,
#  'latitude': 45.4789575,
#  'longitude': -122.6202643,
#  'name': 'Laughing Planet',
#  'postal_code': 97255.0,
#  'review_count': 155,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1795'),
#  'address': '2241 W Burnside St',
#  'categories': 'Pizza, Restaurants',
#  'city': 'Portland',
#  'id': 25,
#  'latitude': 45.5234782,
#  'longitude': -122.6972354,
#  'name': 'Pizza Oasis',
#  'postal_code': 97210.0,
#  'review_count': 87,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1796'),
#  'address': '5627 SW Kelly Ave',
#  'categories': 'Bars, Restaurants, American (New), American (Traditional), '
#                'Sports Bars, Nightlife',
#  'city': 'Portland',
#  'id': 26,
#  'latitude': 45.4827956,
#  'longitude': -122.6760019,
#  'name': "Jolly Roger At John's Landing",
#  'postal_code': 97239.0,
#  'review_count': 60,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1797'),
#  'address': '9722 SE Washington St',
#  'categories': 'Restaurants, Seafood, American (Traditional)',
#  'city': 'Portland',
#  'id': 27,
#  'latitude': 45.517338,
#  'longitude': -122.563968,
#  'name': 'Portland Seafood Company',
#  'postal_code': 97216.0,
#  'review_count': 280,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1798'),
#  'address': '3232 NE 82nd Ave',
#  'categories': 'American (New), Nightlife, Bars, Karaoke, Restaurants',
#  'city': 'Portland',
#  'id': 28,
#  'latitude': 45.5459972,
#  'longitude': -122.5785237,
#  'name': 'Moon Dream',
#  'postal_code': 97220.0,
#  'review_count': 9,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1799'),
#  'address': '2229 SE Hawthorne Blvd',
#  'categories': 'Nightlife, Music Venues, Vegetarian, Arts & Entertainment, '
#                'Lounges, Restaurants, Mass Media, Print Media, Bars',
#  'city': 'Portland',
#  'id': 29,
#  'latitude': 45.512142,
#  'longitude': -122.6430726,
#  'name': 'Imbibe Restaurant & Lounge',
#  'postal_code': 97214.0,
#  'review_count': 41,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b179a'),
#  'address': '1800 SW 1st Ave, Ste 130',
#  'categories': 'Cafes, Restaurants, Delis, Sandwiches',
#  'city': 'Portland',
#  'id': 30,
#  'latitude': 45.510138,
#  'longitude': -122.677199,
#  'name': 'Ole Cafe',
#  'postal_code': 97201.0,
#  'review_count': 10,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b179b'),
#  'address': '804 NW 12th Ave',
#  'categories': 'Bars, Food, Restaurants, Beer, Wine & Spirits, Nightlife, '
#                'Italian, Wine Bars, Cocktail Bars',
#  'city': 'Portland',
#  'id': 31,
#  'latitude': 45.5289822,
#  'longitude': -122.6831063,
#  'name': 'Bar Rione',
#  'postal_code': 97209.0,
#  'review_count': 35,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b179c'),
#  'address': '13480 Nw Science Park Dr',
#  'categories': 'Restaurants, Fast Food, Breakfast & Brunch, Tacos, Mexican, '
#                'Tex-Mex',
#  'city': 'Portland',
#  'id': 32,
#  'latitude': 45.5247072,
#  'longitude': -122.8155379,
#  'name': 'Taco Bell',
#  'postal_code': 97229.0,
#  'review_count': 48,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b179d'),
#  'address': '1462 NE 122nd Ave',
#  'categories': 'Chinese, Restaurants, Fast Food',
#  'city': 'Portland',
#  'id': 33,
#  'latitude': 45.533263,
#  'longitude': -122.5373376,
#  'name': 'Panda Express',
#  'postal_code': 97230.0,
#  'review_count': 27,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b179e'),
#  'address': '3905 SE 82nd Ave',
#  'categories': 'Comfort Food, Food, Italian, Food Trucks, Burgers, Restaurants',
#  'city': 'Portland',
#  'id': 34,
#  'latitude': 45.4936755,
#  'longitude': -122.5793608,
#  'name': 'Mac and Tot Box',
#  'postal_code': 97266.0,
#  'review_count': 7,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b179f'),
#  'address': '2701 NW Vaughn St',
#  'categories': 'Cafes, American (Traditional), Restaurants',
#  'city': 'Portland',
#  'id': 35,
#  'latitude': 45.5375748,
#  'longitude': -122.7083825,
#  'name': 'f&b cafe and catering',
#  'postal_code': 97210.0,
#  'review_count': 11,
#  'stars': 2.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a0'),
#  'address': '3207 SE Hawthorne Blvd',
#  'categories': 'Restaurants, Mexican, Barbeque, Food, Tacos, Food Trucks',
#  'city': 'Portland',
#  'id': 36,
#  'latitude': 45.512267,
#  'longitude': -122.6323559,
#  'name': "Matt's BBQ Tacos",
#  'postal_code': 97214.0,
#  'review_count': 112,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a1'),
#  'address': '1305 NW 23rd Ave',
#  'categories': 'Cocktail Bars, Restaurants, American (New), Salad, Nightlife, '
#                'Bars, Sandwiches',
#  'city': 'Portland',
#  'id': 37,
#  'latitude': 45.53217,
#  'longitude': -122.699013,
#  'name': 'Picnic PDX',
#  'postal_code': 97210.0,
#  'review_count': 44,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a2'),
#  'address': '404 NW 11th Ave',
#  'categories': 'Coffee & Tea, Restaurants, Food',
#  'city': 'Portland',
#  'id': 38,
#  'latitude': 45.5260759,
#  'longitude': -122.6819204,
#  'name': 'Boyds Coffee',
#  'postal_code': 97209.0,
#  'review_count': 14,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a3'),
#  'address': '100 NW 10th Ave',
#  'categories': 'Asian Fusion, Mediterranean, Comfort Food, American '
#                '(Traditional), Italian, Noodles, Restaurants',
#  'city': 'Portland',
#  'id': 39,
#  'latitude': 45.5238168,
#  'longitude': -122.6808522,
#  'name': 'Noodles & Company',
#  'postal_code': 97209.0,
#  'review_count': 141,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a4'),
#  'address': '819 N Killingsworth St',
#  'categories': 'Restaurants, Mediterranean, Halal, Middle Eastern',
#  'city': 'Portland',
#  'id': 40,
#  'latitude': 45.5627869,
#  'longitude': -122.6755114,
#  'name': 'Mandi House',
#  'postal_code': 97217.0,
#  'review_count': 72,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a5'),
#  'address': '9500 SE 82nd Ave',
#  'categories': 'Steakhouses, Restaurants',
#  'city': 'Portland',
#  'id': 41,
#  'latitude': 45.4544583,
#  'longitude': -122.5787463,
#  'name': 'Outback Steakhouse',
#  'postal_code': 97266.0,
#  'review_count': 150,
#  'stars': 2.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a6'),
#  'address': '1639 NW Glisan St',
#  'categories': 'Desserts, Food, American (New), Restaurants, Bakeries, '
#                'Breakfast & Brunch',
#  'city': 'Portland',
#  'id': 42,
#  'latitude': 45.5265522,
#  'longitude': -122.688183,
#  'name': 'Wildflower Baking',
#  'postal_code': 97209.0,
#  'review_count': 6,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a7'),
#  'address': '3616 SE Hawthorne Blvd',
#  'categories': 'Chinese, Vietnamese, Restaurants, Asian Fusion, Thai',
#  'city': 'Portland',
#  'id': 43,
#  'latitude': 45.5119301,
#  'longitude': -122.6263452,
#  'name': 'Chopsticks',
#  'postal_code': 97214.0,
#  'review_count': 36,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a8'),
#  'address': '1527 SW 2nd Ave',
#  'categories': 'Mediterranean, Food, Bars, Vegetarian, Food Trucks, '
#                'Gluten-Free, Nightlife, Middle Eastern, Restaurants',
#  'city': 'Portland',
#  'id': 44,
#  'latitude': 45.5228622485,
#  'longitude': -122.6724387118,
#  'name': 'Gonzo At Bar XV',
#  'postal_code': 97204.0,
#  'review_count': 75,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17a9'),
#  'address': '1128 SW Alder St',
#  'categories': 'Tapas Bars, Restaurants',
#  'city': 'Portland',
#  'id': 45,
#  'latitude': 45.5211215191,
#  'longitude': -122.6835216,
#  'name': 'Pollo Bravo',
#  'postal_code': 97205.0,
#  'review_count': 25,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17aa'),
#  'address': '1299 SE Lexington St',
#  'categories': 'Food Trucks, Food, Restaurants, Mexican',
#  'city': 'Portland',
#  'id': 46,
#  'latitude': 45.4672699,
#  'longitude': -122.6531317,
#  'name': 'Taqueria Luna',
#  'postal_code': 97202.0,
#  'review_count': 21,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ab'),
#  'address': '10175 SE Stark St',
#  'categories': 'Restaurants, Food Stands, Mexican',
#  'city': 'Portland',
#  'id': 47,
#  'latitude': 45.5192806032,
#  'longitude': -122.5585593831,
#  'name': 'Taqueria Antojitos Yucateco',
#  'postal_code': 97216.0,
#  'review_count': 65,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ac'),
#  'address': '432 SW 3rd Ave',
#  'categories': 'Restaurants, Food Stands, Kebab, Persian/Iranian, Fast Food',
#  'city': 'Portland',
#  'id': 48,
#  'latitude': 45.5198475,
#  'longitude': -122.6742938,
#  'name': 'Kabob Kabob Persian Food',
#  'postal_code': 97204.0,
#  'review_count': 6,
#  'stars': 5.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ad'),
#  'address': '4906 NE 122nd Ave',
#  'categories': 'Delis, Sandwiches, Food, Burgers, Restaurants',
#  'city': 'Portland',
#  'id': 49,
#  'latitude': 45.558765,
#  'longitude': -122.53718,
#  'name': "Devaki's Deli",
#  'postal_code': 97230.0,
#  'review_count': 11,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ae'),
#  'address': '1533 NE Alberta St',
#  'categories': 'Food, Italian, Food Trucks, Restaurants, Food Stands',
#  'city': 'Portland',
#  'id': 50,
#  'latitude': 45.5592431,
#  'longitude': -122.648928,
#  'name': 'Certo',
#  'postal_code': 97211.0,
#  'review_count': 9,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17af'),
#  'address': '3808 N Williams Ave',
#  'categories': 'Vegetarian, Restaurants, Vegan',
#  'city': 'Portland',
#  'id': 51,
#  'latitude': 45.5503455,
#  'longitude': -122.6665844,
#  'name': 'Nutshell',
#  'postal_code': 97227.0,
#  'review_count': 26,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b0'),
#  'address': '330 SW 11th St',
#  'categories': 'Restaurants, Seafood, Gay Bars, Bars, Nightlife',
#  'city': 'Portland',
#  'id': 52,
#  'latitude': 45.5224014,
#  'longitude': -122.6818992,
#  'name': 'Boxxes Video Bar',
#  'postal_code': 97205.0,
#  'review_count': 17,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b1'),
#  'address': 'A La Carts Food Pavillion, SE 50th Ave & SE Division St',
#  'categories': 'Restaurants, Hot Dogs, American (Traditional), Food Stands, '
#                'Food',
#  'city': 'Portland',
#  'id': 53,
#  'latitude': 45.484834,
#  'longitude': -122.598102,
#  'name': 'We Be Weiners',
#  'postal_code': 97206.0,
#  'review_count': 9,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b2'),
#  'address': '14790 SE Webster Rd',
#  'categories': 'Restaurants, Shopping, Chinese, Home & Garden, Nurseries & '
#                'Gardening',
#  'city': 'Portland',
#  'id': 54,
#  'latitude': 45.4165053,
#  'longitude': -122.5928369,
#  'name': "Chan's Garden",
#  'postal_code': 97267.0,
#  'review_count': 14,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b3'),
#  'address': '126 SW 2nd Ave',
#  'categories': 'Restaurants, Latin American',
#  'city': 'Portland',
#  'id': 55,
#  'latitude': 45.5215004,
#  'longitude': -122.6724068,
#  'name': 'Teote Outpost',
#  'postal_code': 97204.0,
#  'review_count': 21,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b4'),
#  'address': '7004 N Catlin Ave',
#  'categories': 'Bars, American (New), Restaurants, Nightlife',
#  'city': 'Portland',
#  'id': 56,
#  'latitude': 45.5937668,
#  'longitude': -122.7617864,
#  'name': 'Your Inn Tavern',
#  'postal_code': 97203.0,
#  'review_count': 40,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b5'),
#  'address': '8001 SE Powell Blvd, Ste O',
#  'categories': 'Barbeque, Korean, Restaurants',
#  'city': 'Portland',
#  'id': 57,
#  'latitude': 45.4990766,
#  'longitude': -122.5802742,
#  'name': 'Kkoki Korean BBQ - Portland',
#  'postal_code': 97206.0,
#  'review_count': 86,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b6'),
#  'address': '7405 Barbur Blvd',
#  'categories': 'Pizza, Restaurants, Italian, Chicken Wings',
#  'city': 'Portland',
#  'id': 58,
#  'latitude': 45.4717738,
#  'longitude': -122.6858939,
#  'name': 'Pizza Hut',
#  'postal_code': 97219.0,
#  'review_count': 31,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b7'),
#  'address': '3975 SW Beaverton Hillsdale Hwy',
#  'categories': 'Kosher, Food, Halal, Food Trucks, Restaurants, Barbeque',
#  'city': 'Portland',
#  'id': 59,
#  'latitude': 45.4853202,
#  'longitude': -122.7178121,
#  'name': 'Holy Smokes Righteous Eats',
#  'postal_code': 97221.0,
#  'review_count': 32,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b8'),
#  'address': '11140 SE Powell Blvd',
#  'categories': 'American (Traditional), Soul Food, Southern, Barbeque, Comfort '
#                'Food, Restaurants',
#  'city': 'Portland',
#  'id': 60,
#  'latitude': 45.495806,
#  'longitude': -122.548422,
#  'name': "Reo's Ribs",
#  'postal_code': 97266.0,
#  'review_count': 54,
#  'stars': 2.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17b9'),
#  'address': '4831 NE Fremont St',
#  'categories': 'Pizza, Salad, Italian, Restaurants, Food, Food Delivery '
#                'Services',
#  'city': 'Portland',
#  'id': 61,
#  'latitude': 45.5483779653,
#  'longitude': -122.6131725311,
#  'name': 'Pizza Nostra',
#  'postal_code': 97213.0,
#  'review_count': 143,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ba'),
#  'address': '13485 NW Cornell Rd',
#  'categories': 'Grocery, Delis, Drugstores, Restaurants, Food, Bakeries, '
#                'Shopping',
#  'city': 'Portland',
#  'id': 62,
#  'latitude': 45.5279674,
#  'longitude': -122.8144201,
#  'name': 'Safeway',
#  'postal_code': 97229.0,
#  'review_count': 52,
#  'stars': 2.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17bb'),
#  'address': '704 NW 21st Ave',
#  'categories': 'Restaurants, Indian, Wine Bars, Nightlife, Event Planning & '
#                'Services, Bars, Vegetarian, Cocktail Bars, Venues & Event '
#                'Spaces, Vegan',
#  'city': 'Portland',
#  'id': 63,
#  'latitude': 45.5278598478,
#  'longitude': -122.694169879,
#  'name': 'Bhuna',
#  'postal_code': 97209.0,
#  'review_count': 131,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17bc'),
#  'address': '1831 N Killingsworth St',
#  'categories': 'Breakfast & Brunch, Food, Restaurants, Coffee & Tea',
#  'city': 'Portland',
#  'id': 64,
#  'latitude': 45.5629371,
#  'longitude': -122.6862232,
#  'name': 'The Stacks Coffeehouse',
#  'postal_code': 97217.0,
#  'review_count': 37,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17bd'),
#  'address': '433 NW 10th Ave',
#  'categories': 'Salad, Restaurants, Delis, Cafes, American (Traditional)',
#  'city': 'Portland',
#  'id': 65,
#  'latitude': 45.5263018,
#  'longitude': -122.6815055,
#  'name': 'GP Kitchen',
#  'postal_code': 97209.0,
#  'review_count': 10,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17be'),
#  'address': '3766 SE Hawthorne Blvd',
#  'categories': 'American (Traditional), Restaurants',
#  'city': 'Portland',
#  'id': 66,
#  'latitude': 45.51196,
#  'longitude': -122.624594,
#  'name': 'Tabor Hill Cafe',
#  'postal_code': 97214.0,
#  'review_count': 44,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17bf'),
#  'address': '108 NE 28th Ave',
#  'categories': 'Restaurants, Mexican',
#  'city': 'Portland',
#  'id': 67,
#  'latitude': 45.5237001074,
#  'longitude': -122.6371273784,
#  'name': 'Fonda Rosa',
#  'postal_code': 97232.0,
#  'review_count': 153,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c0'),
#  'address': '7101 NE 82nd Ave',
#  'categories': 'Restaurants, American (Traditional)',
#  'city': 'Portland',
#  'id': 68,
#  'latitude': 45.5743094,
#  'longitude': -122.5793881,
#  'name': 'Pacific Grille',
#  'postal_code': 97220.0,
#  'review_count': 17,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c1'),
#  'address': '625 NE Killingsworth St',
#  'categories': 'Sandwiches, Food Trucks, Burgers, Food Stands, Restaurants, '
#                'Food',
#  'city': 'Portland',
#  'id': 69,
#  'latitude': 45.5629014,
#  'longitude': -122.6589565,
#  'name': 'TNT Grillin',
#  'postal_code': 97211.0,
#  'review_count': 5,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c2'),
#  'address': '701 E Burnside St',
#  'categories': 'Pubs, Bars, Food, American (New), Nightlife, Breakfast & '
#                'Brunch, Breweries, Restaurants',
#  'city': 'Portland',
#  'id': 70,
#  'latitude': 45.5233947,
#  'longitude': -122.6583722,
#  'name': 'Burnside Brewing',
#  'postal_code': 97214.0,
#  'review_count': 538,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c3'),
#  'address': '820 NE 27th Ave',
#  'categories': 'American (New), Chicken Shop, Restaurants',
#  'city': 'Portland',
#  'id': 71,
#  'latitude': 45.5290499433,
#  'longitude': -122.638252,
#  'name': 'Basilisk',
#  'postal_code': 97232.0,
#  'review_count': 497,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c4'),
#  'address': '5135 SE Foster Rd',
#  'categories': 'Sandwiches, Restaurants, Fast Food',
#  'city': 'Portland',
#  'id': 72,
#  'latitude': 45.4961907591,
#  'longitude': -122.6093193826,
#  'name': 'Subway',
#  'postal_code': 97206.0,
#  'review_count': 21,
#  'stars': 2.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c5'),
#  'address': 'A La Carts Food Pavillion, SE 50th Ave & SE Division St',
#  'categories': 'Restaurants, Food Stands, Burgers',
#  'city': 'Portland',
#  'id': 73,
#  'latitude': 45.5053663,
#  'longitude': -122.5998345,
#  'name': 'Over the Top',
#  'postal_code': 97206.0,
#  'review_count': 22,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c6'),
#  'address': '1613 SE Bybee Blvd',
#  'categories': 'Ramen, Japanese, Restaurants',
#  'city': 'Portland',
#  'id': 74,
#  'latitude': 45.4737835754,
#  'longitude': -122.649564743,
#  'name': 'Boxer Ramen',
#  'postal_code': 97202.0,
#  'review_count': 42,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c7'),
#  'address': '9469 SW Washington Square Rd',
#  'categories': 'Pretzels, Food, Fast Food, Restaurants, Bakeries',
#  'city': 'Portland',
#  'id': 75,
#  'latitude': 45.4494683,
#  'longitude': -122.7833414,
#  'name': "Auntie Anne's",
#  'postal_code': 97223.0,
#  'review_count': 12,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c8'),
#  'address': '3145 SE Hawthorne Blvd',
#  'categories': 'Noodles, Restaurants, Thai, Comfort Food',
#  'city': 'Portland',
#  'id': 76,
#  'latitude': 45.512252,
#  'longitude': -122.6328667,
#  'name': 'Khao Moo Dang',
#  'postal_code': 97214.0,
#  'review_count': 67,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17c9'),
#  'address': '6821 SW Beaverton Hillsdale Hwy',
#  'categories': 'Arts & Entertainment, Music Venues, Bars, Food, Pubs, Beer, '
#                'Wine & Spirits, Restaurants, Irish, Nightlife',
#  'city': 'Portland',
#  'id': 77,
#  'latitude': 45.4868189,
#  'longitude': -122.747285,
#  'name': 'Dublin Pub',
#  'postal_code': 97225.0,
#  'review_count': 91,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ca'),
#  'address': '7405 SW Barbur Blvd',
#  'categories': 'Nightlife, Mexican, Lounges, Bars, Restaurants',
#  'city': 'Portland',
#  'id': 78,
#  'latitude': 45.4716244201,
#  'longitude': -122.6859033109,
#  'name': 'La Costita',
#  'postal_code': 97219.0,
#  'review_count': 95,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17cb'),
#  'address': '816 N Russell St',
#  'categories': 'Bars, American (New), Nightlife, Lounges, Restaurants, '
#                'Cocktail Bars',
#  'city': 'Portland',
#  'id': 79,
#  'latitude': 45.5409362,
#  'longitude': -122.6750666,
#  'name': 'Mint 820',
#  'postal_code': 97227.0,
#  'review_count': 268,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17cc'),
#  'address': '1122 SE Tacoma St',
#  'categories': 'Food Trucks, Food, Restaurants, Food Stands, Street Vendors',
#  'city': 'Portland',
#  'id': 80,
#  'latitude': 45.4642245,
#  'longitude': -122.6544946,
#  'name': "Papa Lee's Kitchen",
#  'postal_code': 97202.0,
#  'review_count': 42,
#  'stars': 5.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17cd'),
#  'address': '930 SE Oak St',
#  'categories': 'Food Trucks, Restaurants, Southern, Food',
#  'city': 'Portland',
#  'id': 81,
#  'latitude': 45.519926,
#  'longitude': -122.656011,
#  'name': 'South',
#  'postal_code': 97214.0,
#  'review_count': 49,
#  'stars': 5.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ce'),
#  'address': '701 SW Broadway',
#  'categories': 'Cafes, Diners, American (New), Restaurants',
#  'city': 'Portland',
#  'id': 82,
#  'latitude': 45.519155,
#  'longitude': -122.6803131,
#  'name': 'Café Nordstrom',
#  'postal_code': 97205.0,
#  'review_count': 8,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17cf'),
#  'address': '1909 SW 6th Ave',
#  'categories': 'Local Flavor, Fast Food, Gluten-Free, Pizza, Restaurants',
#  'city': 'Portland',
#  'id': 83,
#  'latitude': 45.5102042,
#  'longitude': -122.6834488,
#  'name': 'HOTLIPS Pizza - PSU',
#  'postal_code': 97201.0,
#  'review_count': 194,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d0'),
#  'address': '12500 NE Sandy Blvd',
#  'categories': 'Bars, Nightlife, American (New), Restaurants, Pubs',
#  'city': 'Portland',
#  'id': 84,
#  'latitude': 45.5561028,
#  'longitude': -122.5335364,
#  'name': 'The Wooden Chicken',
#  'postal_code': 97230.0,
#  'review_count': 110,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d1'),
#  'address': '7304 N Leavitt Ave',
#  'categories': 'Coffee & Tea, Restaurants, Sandwiches, Food, Coffee '
#                'Roasteries, Internet Cafes, Bagels',
#  'city': 'Portland',
#  'id': 85,
#  'latitude': 45.5892997,
#  'longitude': -122.754006,
#  'name': 'St Johns Coffee Roasters',
#  'postal_code': 97203.0,
#  'review_count': 97,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d2'),
#  'address': '12000 SE 82nd Ave',
#  'categories': 'Pretzels, Fast Food, Food, Restaurants, Bakeries',
#  'city': 'Portland',
#  'id': 86,
#  'latitude': 45.435855,
#  'longitude': -122.572803,
#  'name': "Auntie Anne's",
#  'postal_code': 97266.0,
#  'review_count': 21,
#  'stars': 1.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d3'),
#  'address': '10859 SE 82nd Ave',
#  'categories': 'Seafood, Restaurants',
#  'city': 'Portland',
#  'id': 87,
#  'latitude': 45.4443465,
#  'longitude': -122.5792748,
#  'name': "Skipper's Seafood'n Chowder House",
#  'postal_code': 97266.0,
#  'review_count': 11,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d4'),
#  'address': '8414 SE 32nd Ave',
#  'categories': 'Middle Eastern, Halal, Restaurants, Mediterranean',
#  'city': 'Portland',
#  'id': 88,
#  'latitude': 45.4623912,
#  'longitude': -122.6295169,
#  'name': 'Gyro Grill',
#  'postal_code': 97222.0,
#  'review_count': 67,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d5'),
#  'address': '8302 N Lombard St',
#  'categories': 'Pizza, Restaurants',
#  'city': 'Portland',
#  'id': 89,
#  'latitude': 45.5891878,
#  'longitude': -122.7523311,
#  'name': 'Signal Station Pizza',
#  'postal_code': 97203.0,
#  'review_count': 138,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d6'),
#  'address': '126 SW 2nd Ave',
#  'categories': 'Pizza, Restaurants',
#  'city': 'Portland',
#  'id': 90,
#  'latitude': 45.5214549602,
#  'longitude': -122.6723356918,
#  'name': 'Checkerboard Pizza',
#  'postal_code': 97204.0,
#  'review_count': 60,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d7'),
#  'address': '8303 SE Insley St',
#  'categories': 'Kitchen & Bath, Restaurant Supplies, Home & Garden, '
#                'Restaurants, Professional Services, Wholesale Stores, '
#                'Wholesalers, Shopping',
#  'city': 'Portland',
#  'id': 91,
#  'latitude': 45.483826,
#  'longitude': -122.577451,
#  'name': 'Hongs Restaurant Equipment & Supplies',
#  'postal_code': 97266.0,
#  'review_count': 7,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d8'),
#  'address': '17502 SE McLoughlin Blvd',
#  'categories': 'American (Traditional), Cafes, Breakfast & Brunch, Restaurants',
#  'city': 'Portland',
#  'id': 92,
#  'latitude': 45.3956555,
#  'longitude': -122.6159695,
#  'name': 'Biscuits Cafe',
#  'postal_code': 97267.0,
#  'review_count': 20,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17d9'),
#  'address': '12832 NE Airport Way',
#  'categories': 'Car Dealers, Automotive, Restaurants, Pizza',
#  'city': 'Portland',
#  'id': 94,
#  'latitude': 45.5625589879,
#  'longitude': -122.5286962341,
#  'name': 'Moda Cars',
#  'postal_code': 97230.0,
#  'review_count': 6,
#  'stars': 1.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17da'),
#  'address': '1331 N Killingsworth',
#  'categories': 'Food Stands, Food, Food Trucks, Restaurants, Hungarian, Street '
#                'Vendors',
#  'city': 'Portland',
#  'id': 95,
#  'latitude': 45.5626737,
#  'longitude': -122.6808516,
#  'name': 'Hungaricana',
#  'postal_code': 97217.0,
#  'review_count': 7,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17db'),
#  'address': '2137 E Burnside St, Ste D',
#  'categories': 'Restaurants, Sandwiches',
#  'city': 'Portland',
#  'id': 96,
#  'latitude': 45.5231622,
#  'longitude': -122.6437679,
#  'name': 'Knuckle Sandwich',
#  'postal_code': 97214.0,
#  'review_count': 70,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17dc'),
#  'address': '121 SW 3rd Avenue',
#  'categories': 'Restaurants, Steakhouses',
#  'city': 'Portland',
#  'id': 97,
#  'latitude': 45.5221926,
#  'longitude': -122.673869,
#  'name': 'Portland Steak & Chophouse',
#  'postal_code': 97204.0,
#  'review_count': 9,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17dd'),
#  'address': '3200 SE Milwaukie Ave',
#  'categories': 'Breakfast & Brunch, Restaurants',
#  'city': 'Portland',
#  'id': 98,
#  'latitude': 45.5001642,
#  'longitude': -122.6539839,
#  'name': "Sanborn's",
#  'postal_code': 97202.0,
#  'review_count': 346,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17de'),
#  'address': '1621 SE Bybee Blvd',
#  'categories': 'Salad, Restaurants, Bars, Nightlife, Beverage Store, Soup, '
#                'American (Traditional), Burgers, Food, Breweries, Pubs, Beer, '
#                'Wine & Spirits, Sandwiches',
#  'city': 'Portland',
#  'id': 99,
#  'latitude': 45.4738802,
#  'longitude': -122.6494217,
#  'name': 'Oaks Bottom Public House',
#  'postal_code': 97202.0,
#  'review_count': 217,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17df'),
#  'address': '211 SW 6th Ave',
#  'categories': 'Sandwiches, Restaurants, Nightlife, Bars, Breakfast & Brunch',
#  'city': 'Portland',
#  'id': 100,
#  'latitude': 45.522186849,
#  'longitude': -122.6770756159,
#  'name': 'Bunk',
#  'postal_code': 97204.0,
#  'review_count': 203,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e0'),
#  'address': '828 SE Ash St',
#  'categories': 'Diners, Event Planning & Services, Restaurants, American '
#                '(New), American (Traditional), Beer, Wine & Spirits, Local '
#                'Flavor, Italian, Caterers, Sandwiches, Food, Breakfast & '
#                'Brunch',
#  'city': 'Portland',
#  'id': 101,
#  'latitude': 45.5213705,
#  'longitude': -122.6570574,
#  'name': 'Simpatica Dining Hall',
#  'postal_code': 97214.0,
#  'review_count': 247,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e1'),
#  'address': '17110 SE Powell Blvd',
#  'categories': 'Chinese, Restaurants',
#  'city': 'Portland',
#  'id': 102,
#  'latitude': 45.4924861,
#  'longitude': -122.4873637,
#  'name': "Chu's Eatery",
#  'postal_code': 97236.0,
#  'review_count': 71,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e2'),
#  'address': '1037 SW Morrison St',
#  'categories': 'Restaurants, Thai',
#  'city': 'Portland',
#  'id': 103,
#  'latitude': 45.5203279,
#  'longitude': -122.6828747,
#  'name': 'Thai Time Cafe',
#  'postal_code': 97205.0,
#  'review_count': 73,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e3'),
#  'address': '5235 NE Sandy Blvd',
#  'categories': 'Food Trucks, Vegan, Gluten-Free, Burgers, Restaurants, Food',
#  'city': 'Portland',
#  'id': 104,
#  'latitude': 45.540755305,
#  'longitude': -122.6093143185,
#  'name': 'The Mocking Bird',
#  'postal_code': 97213.0,
#  'review_count': 49,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e4'),
#  'address': '108 SW Pine St',
#  'categories': 'Nightlife, Bars, Thai, Food, Restaurants, Event Planning & '
#                'Services, Beer, Wine & Spirits, Caterers',
#  'city': 'Portland',
#  'id': 105,
#  'latitude': 45.5209573,
#  'longitude': -122.6722422,
#  'name': 'Maiphai Thai Cuisine',
#  'postal_code': 97204.0,
#  'review_count': 104,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e5'),
#  'address': '2137 E Burnside',
#  'categories': 'Restaurants, Vegetarian, Cuban, Latin American, Vegan',
#  'city': 'Portland',
#  'id': 106,
#  'latitude': 45.5231822,
#  'longitude': -122.6437529,
#  'name': 'Miami Nice',
#  'postal_code': 97232.0,
#  'review_count': 27,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e6'),
#  'address': 'SW 6th Ave and Columbia',
#  'categories': 'Breakfast & Brunch, Restaurants, Food, Food Stands, Bagels',
#  'city': 'Portland',
#  'id': 107,
#  'latitude': 45.514428,
#  'longitude': -122.681189,
#  'name': 'Rescue Bagels',
#  'postal_code': 97201.0,
#  'review_count': 23,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e7'),
#  'address': '14919 SE Stark St',
#  'categories': 'American (Traditional), Mexican, Restaurants',
#  'city': 'Portland',
#  'id': 108,
#  'latitude': 45.5193294672,
#  'longitude': -122.5095614791,
#  'name': 'Jalapeño Grill',
#  'postal_code': 97233.0,
#  'review_count': 5,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e8'),
#  'address': '1800 NE Alberta St',
#  'categories': 'Bars, Restaurants, Coffee & Tea, Bakeries, Food, Desserts, '
#                'Nightlife',
#  'city': 'Portland',
#  'id': 109,
#  'latitude': 45.5589826754,
#  'longitude': -122.6466879457,
#  'name': 'Random Order Pie Bar',
#  'postal_code': 97211.0,
#  'review_count': 514,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17e9'),
#  'address': '901 N Anchor Way',
#  'categories': 'Mexican, Burgers, Food, Restaurants',
#  'city': 'Portland',
#  'id': 110,
#  'latitude': 45.6031466,
#  'longitude': -122.6762632,
#  'name': 'Chompers Growlers & Cantina Cantinflas',
#  'postal_code': 97217.0,
#  'review_count': 10,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ea'),
#  'address': '1930 SW 4th Ave',
#  'categories': 'Restaurants, Mexican',
#  'city': 'Portland',
#  'id': 111,
#  'latitude': 45.5090477,
#  'longitude': -122.6809337,
#  'name': 'Taco Del Mar',
#  'postal_code': 97207.0,
#  'review_count': 27,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17eb'),
#  'address': '3805 SE 52nd Ave',
#  'categories': 'Karaoke, American (Traditional), Dive Bars, Restaurants, Bars, '
#                'Nightlife',
#  'city': 'Portland',
#  'id': 112,
#  'latitude': 45.4952678,
#  'longitude': -122.6092467,
#  'name': 'The Trap Restaurant',
#  'postal_code': 97206.0,
#  'review_count': 42,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ec'),
#  'address': '5225 N Lombard St',
#  'categories': 'Restaurants, Mexican',
#  'city': 'Portland',
#  'id': 113,
#  'latitude': 45.5819776,
#  'longitude': -122.7220669,
#  'name': 'Cha Cha Cha Taqueria',
#  'postal_code': 97203.0,
#  'review_count': 211,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ed'),
#  'address': '2348 SE Ankeny St',
#  'categories': 'Italian, Restaurants',
#  'city': 'Portland',
#  'id': 114,
#  'latitude': 45.5220507,
#  'longitude': -122.6416291,
#  'name': 'Il Piatto',
#  'postal_code': 97214.0,
#  'review_count': 92,
#  'stars': 2.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ee'),
#  'address': '6238 SW Capitol Hwy',
#  'categories': 'Food Stands, Restaurants, Asian Fusion',
#  'city': 'Portland',
#  'id': 115,
#  'latitude': 45.4787968,
#  'longitude': -122.6931126,
#  'name': 'Phat Cart',
#  'postal_code': 97239.0,
#  'review_count': 35,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ef'),
#  'address': '3801 SE Belmont St',
#  'categories': 'Restaurants, Thai',
#  'city': 'Portland',
#  'id': 116,
#  'latitude': 45.51659,
#  'longitude': -122.6242609,
#  'name': 'Blue Basil Thai Cuisine',
#  'postal_code': 97214.0,
#  'review_count': 32,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f0'),
#  'address': '1231 N Anchor Way',
#  'categories': 'Food, Internet Cafes, Cafes, Restaurants',
#  'city': 'Portland',
#  'id': 117,
#  'latitude': 45.6048415,
#  'longitude': -122.6787581,
#  'name': 'North Harbour Cafe',
#  'postal_code': 97217.0,
#  'review_count': 6,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f1'),
#  'address': '2035 NE 41st Ave',
#  'categories': 'Sandwiches, Coffee & Tea, Restaurants, Food',
#  'city': 'Portland',
#  'id': 118,
#  'latitude': 45.5376095,
#  'longitude': -122.6212403,
#  'name': 'Rain City Coffee',
#  'postal_code': 97212.0,
#  'review_count': 11,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f2'),
#  'address': '71 SW 2nd Ave',
#  'categories': 'Music Venues, Nightlife, Tapas/Small Plates, American '
#                '(Traditional), Restaurants, Lounges, Breakfast & Brunch, Arts '
#                '& Entertainment, Bars, Dance Clubs',
#  'city': 'Portland',
#  'id': 119,
#  'latitude': 45.5222443,
#  'longitude': -122.6724998,
#  'name': 'Senate',
#  'postal_code': 97204.0,
#  'review_count': 29,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f3'),
#  'address': '1700 N Killingsworth Street',
#  'categories': 'Cajun/Creole, French, Restaurants',
#  'city': 'Portland',
#  'id': 120,
#  'latitude': 45.562554,
#  'longitude': -122.685083,
#  'name': 'Roux',
#  'postal_code': 97255.0,
#  'review_count': 57,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f4'),
#  'address': '602 SE Salmon St',
#  'categories': 'Breakfast & Brunch, Food Trucks, Tex-Mex, Food Stands, Tacos, '
#                'Restaurants, Food, Mexican',
#  'city': 'Portland',
#  'id': 121,
#  'latitude': 45.5142401314,
#  'longitude': -122.6596239382,
#  'name': 'Tight Tacos',
#  'postal_code': 97214.0,
#  'review_count': 142,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f5'),
#  'address': '1422 NW 23rd Ave',
#  'categories': 'Pubs, American (Traditional), Restaurants, Bars, Whiskey Bars, '
#                'Barbeque, Nightlife, Southern',
#  'city': 'Portland',
#  'id': 122,
#  'latitude': 45.5330418,
#  'longitude': -122.6985210425,
#  'name': 'Southland Whiskey Kitchen',
#  'postal_code': 97210.0,
#  'review_count': 510,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f6'),
#  'address': '3714 SW Macadam Ave',
#  'categories': 'Japanese, Asian Fusion, Japanese Curry, Restaurants',
#  'city': 'Portland',
#  'id': 123,
#  'latitude': 45.4962094,
#  'longitude': -122.6725594,
#  'name': 'Umai Japanese Twist',
#  'postal_code': 97239.0,
#  'review_count': 14,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f7'),
#  'address': '8111 SE Foster Rd',
#  'categories': 'Cajun/Creole, American (Traditional), Restaurants, Food, Fast '
#                'Food, Desserts, Chicken Wings',
#  'city': 'Portland',
#  'id': 124,
#  'latitude': 45.483279,
#  'longitude': -122.5793376,
#  'name': 'Popeyes Louisiana Kitchen',
#  'postal_code': 97206.0,
#  'review_count': 99,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f8'),
#  'address': '2636 NE Sandy Blvd, Ste F',
#  'categories': 'Vegan, Food, Ice Cream & Frozen Yogurt, Restaurants',
#  'city': 'Portland',
#  'id': 125,
#  'latitude': 45.5283148,
#  'longitude': -122.6386321,
#  'name': "Kate's Ice Cream",
#  'postal_code': 97232.0,
#  'review_count': 25,
#  'stars': 5.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17f9'),
#  'address': 'NE 11th & Alberta St',
#  'categories': 'Restaurants, Food Trucks, Hawaiian, Food, Asian Fusion',
#  'city': 'Portland',
#  'id': 126,
#  'latitude': 45.5590997,
#  'longitude': -122.6546088,
#  'name': 'Lilikoi',
#  'postal_code': 97217.0,
#  'review_count': 92,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17fa'),
#  'address': '6341 SW Capitol Hwy',
#  'categories': 'Restaurants, Chinese, Nightlife, Food, Thai, Sushi Bars, Bars',
#  'city': 'Portland',
#  'id': 127,
#  'latitude': 45.4786998,
#  'longitude': -122.6955135,
#  'name': 'City Thai Portland',
#  'postal_code': 97239.0,
#  'review_count': 233,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17fb'),
#  'address': '8421 SW Terwilliger Blvd',
#  'categories': 'Restaurants, Mediterranean',
#  'city': 'Portland',
#  'id': 128,
#  'latitude': 45.4639955,
#  'longitude': -122.6843247,
#  'name': 'Moonlight Grill',
#  'postal_code': 97219.0,
#  'review_count': 8,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17fc'),
#  'address': '7237 N Philadelphia Ave',
#  'categories': 'Salad, Restaurants, Pizza',
#  'city': 'Portland',
#  'id': 129,
#  'latitude': 45.5895935,
#  'longitude': -122.755854,
#  'name': 'Pizza Nostra',
#  'postal_code': 97203.0,
#  'review_count': 64,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17fd'),
#  'address': '2788 SE 82nd Ave, Ste 103',
#  'categories': 'Restaurants, Chinese',
#  'city': 'Portland',
#  'id': 130,
#  'latitude': 45.5023567,
#  'longitude': -122.5784636,
#  'name': 'Yan Zi Lou',
#  'postal_code': 97266.0,
#  'review_count': 29,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17fe'),
#  'address': '8220 SE Harrison St, Ste 138a',
#  'categories': 'Chinese, Restaurants, Japanese, Delis, Korean, Vietnamese',
#  'city': 'Portland',
#  'id': 131,
#  'latitude': 45.5082178,
#  'longitude': -122.5784607,
#  'name': 'Jin Jin Deli',
#  'postal_code': 97216.0,
#  'review_count': 89,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b17ff'),
#  'address': '1122 SE Tacoma St',
#  'categories': 'Desserts, Food Trucks, Sandwiches, French, Bakeries, American '
#                '(New), Restaurants, Food',
#  'city': 'Portland',
#  'id': 132,
#  'latitude': 45.464174,
#  'longitude': -122.654402,
#  'name': 'Village Patisserie',
#  'postal_code': 97202.0,
#  'review_count': 25,
#  'stars': 5.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1800'),
#  'address': '401 SE Caruthers St',
#  'categories': 'Food, Breweries, Restaurants, Ice Cream & Frozen Yogurt, Pizza',
#  'city': 'Portland',
#  'id': 133,
#  'latitude': 45.5063784,
#  'longitude': -122.6615804,
#  'name': 'Mt. Hood Brewing Co. - Tilikum Station',
#  'postal_code': 97214.0,
#  'review_count': 70,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1801'),
#  'address': '4290 SE Belmont St',
#  'categories': 'Street Vendors, Thai, Food Stands, Restaurants, Food',
#  'city': 'Portland',
#  'id': 134,
#  'latitude': 45.5165514,
#  'longitude': -122.6179155,
#  'name': 'Yum Zap',
#  'postal_code': 97215.0,
#  'review_count': 21,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1802'),
#  'address': '5230 NE Sandy Blvd',
#  'categories': 'Food Trucks, Chinese, Street Vendors, Restaurants, Food',
#  'city': 'Portland',
#  'id': 135,
#  'latitude': 45.540286073,
#  'longitude': -122.6094328612,
#  'name': "Chen's Express",
#  'postal_code': 97213.0,
#  'review_count': 52,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1803'),
#  'address': '625 NE Killingsworth St',
#  'categories': 'Smokehouse, Food, Barbeque, Restaurants',
#  'city': 'Portland',
#  'id': 136,
#  'latitude': 45.5629709,
#  'longitude': -122.6591093,
#  'name': 'U-Licious Smokehouse & Grill',
#  'postal_code': 97211.0,
#  'review_count': 45,
#  'stars': 2.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b1804'),
#  'address': '916 NW 21st Ave',
#  'categories': 'Restaurants, Pizza',
#  'city': 'Portland',
#  'id': 137,
#  'latitude': 45.529496,
#  'longitude': -122.694267,
#  'name': 'Ranch PDX',
#  'postal_code': 97209.0,
#  'review_count': 45,
#  'stars': 4.5,
#  'state': 'OR'}
# ...
#  'review_count': 35,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d82'),
#  'address': '5425 E Burnside St',
#  'categories': 'American (New), Food, Restaurants',
#  'city': 'Portland',
#  'id': 5685,
#  'latitude': 45.5229038,
#  'longitude': -122.6078135,
#  'name': 'Skin & Bones American Bistro',
#  'postal_code': 97215.0,
#  'review_count': 34,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d83'),
#  'address': '8320 SE Woodstock Blvd',
#  'categories': 'Waffles, Gluten-Free, Coffee & Tea, Restaurants, Food',
#  'city': 'Portland',
#  'id': 5686,
#  'latitude': 45.4792628,
#  'longitude': -122.5772603,
#  'name': 'A Little Nectar',
#  'postal_code': 97266.0,
#  'review_count': 24,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d84'),
#  'address': '1089 NE Grand Ave',
#  'categories': 'Cafes, Restaurants, Food, Bakeries, Desserts',
#  'city': 'Portland',
#  'id': 5687,
#  'latitude': 45.5306892,
#  'longitude': -122.6608139,
#  'name': 'Citizen Baker',
#  'postal_code': 97232.0,
#  'review_count': 98,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d85'),
#  'address': '9830 SE Washington St',
#  'categories': 'Italian, Bars, Wine Bars, Nightlife, Soup, Salad, Restaurants',
#  'city': 'Portland',
#  'id': 5688,
#  'latitude': 45.5181030431,
#  'longitude': -122.5619409762,
#  'name': 'Olive Garden Italian Restaurant',
#  'postal_code': 97216.0,
#  'review_count': 175,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d86'),
#  'address': '3524 N Mississippi Ave',
#  'categories': 'Restaurants, Mexican',
#  'city': 'Portland',
#  'id': 5689,
#  'latitude': 45.5481597,
#  'longitude': -122.6753183,
#  'name': 'Por Qué No? Taqueria',
#  'postal_code': 97227.0,
#  'review_count': 1161,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d87'),
#  'address': '6410 SE Milwaukie Ave',
#  'categories': 'Sandwiches, Food, Cheesesteaks, Beer, Wine & Spirits, '
#                'Restaurants, Breweries',
#  'city': 'Portland',
#  'id': 5690,
#  'latitude': 45.4762533,
#  'longitude': -122.6488352,
#  'name': "Philadelphia's Steaks & Hoagies",
#  'postal_code': 97202.0,
#  'review_count': 84,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d88'),
#  'address': '2444 NW 28th Ave',
#  'categories': 'Breweries, Gastropubs, Brewpubs, Coffee & Tea, Food, '
#                'Restaurants',
#  'city': 'Portland',
#  'id': 5691,
#  'latitude': 45.5397794242,
#  'longitude': -122.7089525662,
#  'name': 'Great Notion Brewing',
#  'postal_code': 97210.0,
#  'review_count': 116,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d89'),
#  'address': '2329 NE Glisan St',
#  'categories': 'Nightlife, Bars, Restaurants, Pubs, Burgers, Salad',
#  'city': 'Portland',
#  'id': 5692,
#  'latitude': 45.5266984571,
#  'longitude': -122.641836001,
#  'name': 'Slowburger',
#  'postal_code': 97232.0,
#  'review_count': 188,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d8a'),
#  'address': '8630 N Lombard St',
#  'categories': 'Restaurants, Bakeries, Specialty Food, Food, Ethnic Food, '
#                'Mexican, Grocery',
#  'city': 'Portland',
#  'id': 5693,
#  'latitude': 45.5902315,
#  'longitude': -122.7552847,
#  'name': 'Tienda Santa Cruz',
#  'postal_code': 97203.0,
#  'review_count': 476,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d8b'),
#  'address': '2548 SE 122nd Ave',
#  'categories': 'Grocery, Local Flavor, Food, Restaurants, Meat Shops, Halal, '
#                'Specialty Food, Indian, Imported Food, International Grocery, '
#                'Shopping',
#  'city': 'Portland',
#  'id': 5694,
#  'latitude': 45.5033981,
#  'longitude': -122.536812,
#  'name': 'Mingala International Market',
#  'postal_code': 97236.0,
#  'review_count': 18,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d8c'),
#  'address': '1900 NW 27th Ave',
#  'categories': 'Diners, Nightlife, Bars, Restaurants, Mexican',
#  'city': 'Portland',
#  'id': 5695,
#  'latitude': 45.5362387,
#  'longitude': -122.7066189,
#  'name': 'Impala',
#  'postal_code': 97210.0,
#  'review_count': 48,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d8d'),
#  'address': '2126 SE Division St',
#  'categories': 'Buffets, Sushi Bars, Japanese, Soup, Restaurants',
#  'city': 'Portland',
#  'id': 5696,
#  'latitude': 45.5046641,
#  'longitude': -122.6440116,
#  'name': 'Sushi Mazi',
#  'postal_code': 97202.0,
#  'review_count': 240,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d8e'),
#  'address': '501 NE Alberta St',
#  'categories': 'Barbeque, Restaurants',
#  'city': 'Portland',
#  'id': 5697,
#  'latitude': 45.5592455,
#  'longitude': -122.6600819,
#  'name': "Po'Shines",
#  'postal_code': 97211.0,
#  'review_count': 16,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d8f'),
#  'address': 'Scholls Ferry & SW N',
#  'categories': 'Restaurants, Burgers',
#  'city': 'Portland',
#  'id': 5698,
#  'latitude': 45.446927,
#  'longitude': -122.789752,
#  'name': 'Burger King',
#  'postal_code': 97223.0,
#  'review_count': 5,
#  'stars': 1.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d90'),
#  'address': '7316 N Lombard St',
#  'categories': 'Food, Mexican, Restaurants, Vegetarian, Food Trucks',
#  'city': 'Portland',
#  'id': 5699,
#  'latitude': 45.5875949855,
#  'longitude': -122.7425441296,
#  'name': 'El Burrito Mojado',
#  'postal_code': 97203.0,
#  'review_count': 25,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d91'),
#  'address': '0672 SW Gaines St',
#  'categories': 'Salad, Italian, American (New), Restaurants, Breakfast & '
#                'Brunch, Pizza',
#  'city': 'Portland',
#  'id': 5700,
#  'latitude': 45.4962719,
#  'longitude': -122.6711247,
#  'name': 'Sweet Heart Pizza',
#  'postal_code': 97239.0,
#  'review_count': 99,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d92'),
#  'address': '426 SW 3rd Ave',
#  'categories': 'Food, Fast Food, Mexican, Food Trucks, Restaurants',
#  'city': 'Portland',
#  'id': 5701,
#  'latitude': 45.519895,
#  'longitude': -122.674803,
#  'name': "Tito's Burritos",
#  'postal_code': 97201.0,
#  'review_count': 9,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d93'),
#  'address': '12505 NW Cornell Rd',
#  'categories': 'Restaurants, Coffee & Tea, Food',
#  'city': 'Portland',
#  'id': 5702,
#  'latitude': 45.526393,
#  'longitude': -122.805441,
#  'name': 'Java Station',
#  'postal_code': 97229.0,
#  'review_count': 5,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d94'),
#  'address': '1930 NE Everett',
#  'categories': 'Food Stands, Restaurants',
#  'city': 'Portland',
#  'id': 5703,
#  'latitude': 45.524781,
#  'longitude': -122.645915,
#  'name': 'King Quesadilla',
#  'postal_code': 97232.0,
#  'review_count': 5,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d95'),
#  'address': '10201 S E Stark St',
#  'categories': 'Food, Restaurants, Hot Dogs, American (Traditional)',
#  'city': 'Portland',
#  'id': 5704,
#  'latitude': 45.519037,
#  'longitude': -122.5584209,
#  'name': 'Weenies From Another World',
#  'postal_code': 97216.0,
#  'review_count': 9,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d96'),
#  'address': '3625 NE Martin Luther King Junior Blvd',
#  'categories': 'Restaurants, Food, Food Trucks, Mexican',
#  'city': 'Portland',
#  'id': 5705,
#  'latitude': 45.5492847407,
#  'longitude': -122.6618720591,
#  'name': '3 Jarritos Food',
#  'postal_code': 97212.0,
#  'review_count': 14,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d97'),
#  'address': '5010 NE Oregon St',
#  'categories': 'Bars, American (Traditional), Wine Bars, Burgers, Nightlife, '
#                'Restaurants',
#  'city': 'Portland',
#  'id': 5706,
#  'latitude': 45.5290610207,
#  'longitude': -122.6115504652,
#  'name': "Clive's Public House",
#  'postal_code': 97213.0,
#  'review_count': 8,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d98'),
#  'address': '4630 SE International Way',
#  'categories': 'Sandwiches, Restaurants',
#  'city': 'Portland',
#  'id': 5707,
#  'latitude': 45.4348961,
#  'longitude': -122.6154626,
#  'name': 'Big Town Hero',
#  'postal_code': 97222.0,
#  'review_count': 23,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d99'),
#  'address': '5121 NE Sandy Blvd',
#  'categories': 'Food Trucks, Food, Mexican, Restaurants',
#  'city': 'Portland',
#  'id': 5708,
#  'latitude': 45.5406910102,
#  'longitude': -122.6093392765,
#  'name': 'El Guero',
#  'postal_code': 97213.0,
#  'review_count': 38,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d9a'),
#  'address': '4641 NE Fremont St',
#  'categories': 'Gluten-Free, Event Planning & Services, Street Vendors, '
#                'Vegetarian, Caterers, Food, Cafes, Restaurants, Farmers '
#                'Market, Food Trucks, American (New)',
#  'city': 'Portland',
#  'id': 5709,
#  'latitude': 45.5483256307,
#  'longitude': -122.6151282465,
#  'name': 'Thrive Sauce & Bowls',
#  'postal_code': 97213.0,
#  'review_count': 99,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d9b'),
#  'address': '1501 NE Broadway St',
#  'categories': 'Nightlife, Sports Bars, Seafood, Dance Clubs, Restaurants, '
#                'Mexican, Bars',
#  'city': 'Portland',
#  'id': 5710,
#  'latitude': 45.5351418,
#  'longitude': -122.6502247,
#  'name': "Aztec Willie's Taqueria",
#  'postal_code': 97232.0,
#  'review_count': 249,
#  'stars': 3.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d9c'),
#  'address': '306 NW Broadway',
#  'categories': 'Lounges, American (New), Restaurants, Bars, Nightlife, Beer, '
#                'Wine & Spirits, Food',
#  'city': 'Portland',
#  'id': 5711,
#  'latitude': 45.5252987,
#  'longitude': -122.6773958,
#  'name': 'Gilt Club',
#  'postal_code': 97209.0,
#  'review_count': 244,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d9d'),
#  'address': '1833 SW 6th Ave',
#  'categories': 'Restaurants, Sandwiches',
#  'city': 'Portland',
#  'id': 5712,
#  'latitude': 45.5114063,
#  'longitude': -122.6829399,
#  'name': 'Best Baguette',
#  'postal_code': 97201.0,
#  'review_count': 47,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d9e'),
#  'address': '9226 SE Division St',
#  'categories': 'Sandwiches, Fast Food, Restaurants',
#  'city': 'Portland',
#  'id': 5713,
#  'latitude': 45.5041226,
#  'longitude': -122.5675246,
#  'name': 'Subway',
#  'postal_code': 97266.0,
#  'review_count': 5,
#  'stars': 2.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2d9f'),
#  'address': '627 SE Morrison St',
#  'categories': 'American (Traditional), Restaurants, Nightlife, Bars',
#  'city': 'Portland',
#  'id': 5714,
#  'latitude': 45.5173439098,
#  'longitude': -122.6590959728,
#  'name': "Creepy's",
#  'postal_code': 97214.0,
#  'review_count': 92,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da0'),
#  'address': '6031 SE Stark St',
#  'categories': 'Nightlife, Pubs, American (Traditional), Bars, Restaurants',
#  'city': 'Portland',
#  'id': 5715,
#  'latitude': 45.519346,
#  'longitude': -122.6016565,
#  'name': 'Caldera Public House',
#  'postal_code': 97215.0,
#  'review_count': 148,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da1'),
#  'address': '12282 SW Scholls Ferry Rd',
#  'categories': 'Pizza, Restaurants, Delis',
#  'city': 'Portland',
#  'id': 5716,
#  'latitude': 45.4433969,
#  'longitude': -122.8032689,
#  'name': 'Pizza Schmizza',
#  'postal_code': 97223.0,
#  'review_count': 8,
#  'stars': 2.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da2'),
#  'address': '2730 S Moody Ave',
#  'categories': 'Sandwiches, Bars, Restaurants, Burgers, Delis, Beer, Wine & '
#                'Spirits, Nightlife, Food, Wine Bars',
#  'city': 'Portland',
#  'id': 5717,
#  'latitude': 45.5032004,
#  'longitude': -122.6718279,
#  'name': 'Elephants Delicatessen at South Waterfront',
#  'postal_code': 97201.0,
#  'review_count': 41,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da3'),
#  'address': '3616 SE Hawthorne Blvd',
#  'categories': 'Noodles, Gluten-Free, Vegetarian, Restaurants, Thai',
#  'city': 'Portland',
#  'id': 5718,
#  'latitude': 45.5118743,
#  'longitude': -122.6264407,
#  'name': 'Mee Gin Soul Kitchen',
#  'postal_code': 97214.0,
#  'review_count': 152,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da4'),
#  'address': '13110 NE Sandy Blvd',
#  'categories': 'Restaurants, American (Traditional), Mexican, Food Trucks, '
#                'Bubble Tea, Food',
#  'city': 'Portland',
#  'id': 5719,
#  'latitude': 45.5552633,
#  'longitude': -122.5280674,
#  'name': 'EL Yucateco Food Cart',
#  'postal_code': 97230.0,
#  'review_count': 65,
#  'stars': 4.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da5'),
#  'address': '3551 SE Division St',
#  'categories': 'Restaurants, Coffee & Tea, Food',
#  'city': 'Portland',
#  'id': 5720,
#  'latitude': 45.5049806,
#  'longitude': -122.6274224,
#  'name': 'Haven Coffee',
#  'postal_code': 97202.0,
#  'review_count': 15,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da6'),
#  'address': 'Rose City Food Park',
#  'categories': 'Bagels, Food Trucks, Sandwiches, Restaurants, Food',
#  'city': 'Portland',
#  'id': 5721,
#  'latitude': 45.543521,
#  'longitude': -122.6086472,
#  'name': 'Bridgetown Bagel Company',
#  'postal_code': 97213.0,
#  'review_count': 58,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da7'),
#  'address': '108 SW Pine St',
#  'categories': 'Cocktail Bars, Asian Fusion, Restaurants, Bars, Nightlife',
#  'city': 'Portland',
#  'id': 5722,
#  'latitude': 45.52094,
#  'longitude': -122.6722,
#  'name': 'Buranko',
#  'postal_code': 97204.0,
#  'review_count': 26,
#  'stars': 5.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da8'),
#  'address': '1230 Nw Hoyt St',
#  'categories': 'Italian, Restaurants',
#  'city': 'Portland',
#  'id': 5723,
#  'latitude': 45.5271502,
#  'longitude': -122.6838655,
#  'name': 'Fratelli',
#  'postal_code': 97209.0,
#  'review_count': 131,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2da9'),
#  'address': 'SE 102nd And Stark',
#  'categories': 'Food Stands, Food, Street Vendors, Restaurants, Thai',
#  'city': 'Portland',
#  'id': 5724,
#  'latitude': 45.5192971967,
#  'longitude': -122.55863628,
#  'name': 'Thai Garden',
#  'postal_code': 97233.0,
#  'review_count': 165,
#  'stars': 4.0,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2daa'),
#  'address': '1629 S.E. Hawthorne Blvd.',
#  'categories': 'Pubs, Breweries, Food, American (Traditional), Bars, '
#                'Nightlife, Restaurants',
#  'city': 'Portland',
#  'id': 5725,
#  'latitude': 45.5124225,
#  'longitude': -122.6487821,
#  'name': 'McMenamins Barley Mill Pub',
#  'postal_code': 97214.0,
#  'review_count': 108,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2dab'),
#  'address': '2266 NW Lovejoy St',
#  'categories': "Fashion, Men's Clothing, Restaurants, Shopping, Women's "
#                'Clothing',
#  'city': 'Portland',
#  'id': 5726,
#  'latitude': 45.529592,
#  'longitude': -122.697685,
#  'name': 'Seaplane',
#  'postal_code': 97210.0,
#  'review_count': 13,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2dac'),
#  'address': '3145 SE Hawthorne Blvd',
#  'categories': 'Italian, Restaurants',
#  'city': 'Portland',
#  'id': 5727,
#  'latitude': 45.5121959,
#  'longitude': -122.6328655,
#  'name': 'The Italian Joint',
#  'postal_code': 97203.0,
#  'review_count': 20,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2dad'),
#  'address': '5700 SW Terwilliger',
#  'categories': 'Event Planning & Services, Steakhouses, Seafood, Venues & '
#                'Event Spaces, American (Traditional), Restaurants',
#  'city': 'Portland',
#  'id': 5728,
#  'latitude': 45.4831538693,
#  'longitude': -122.6827479154,
#  'name': 'Chart House',
#  'postal_code': 97239.0,
#  'review_count': 457,
#  'stars': 3.5,
#  'state': 'OR'}
# {'_id': ObjectId('61aaf3fd66f88d91729b2dae'),
#  'address': '910 NW 14th St',
#  'categories': 'Cuban, Sandwiches, Restaurants, Cafes',
#  'city': 'Portland',
#  'id': 5729,
#  'latitude': 45.5296468,
#  'longitude': -122.6851529,
#  'name': 'Havana Cafe',
#  'postal_code': 97209.0,
#  'review_count': 10,
#  'stars': 4.0,
#  'state': 'OR'}
